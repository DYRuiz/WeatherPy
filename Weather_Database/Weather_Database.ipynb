# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import gmaps
import requests
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url+"&q="+ city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_desc=city_weather['weather'][0]['description']
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description":city_desc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | sao joao da barra
# Processing Record 3 of Set 1 | moses lake
# Processing Record 4 of Set 1 | cedar city
# Processing Record 5 of Set 1 | carbonia
# Processing Record 6 of Set 1 | upernavik
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | gimli
# Processing Record 9 of Set 1 | orotukan
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | rio grande
# Processing Record 14 of Set 1 | souillac
# Processing Record 15 of Set 1 | aklavik
# Processing Record 16 of Set 1 | kralendijk
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | gvardeysk
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | urubamba
# Processing Record 21 of Set 1 | port lincoln
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | araouane
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | esperance
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | coulihaut
# City not found. Skipping...
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | airai
# Processing Record 34 of Set 1 | summerland
# Processing Record 35 of Set 1 | los llanos de aridane
# Processing Record 36 of Set 1 | tuatapere
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | dzaoudzi
# Processing Record 39 of Set 1 | medea
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | kaitangata
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | garchitorena
# Processing Record 45 of Set 1 | heide
# Processing Record 46 of Set 1 | saint-philippe
# Processing Record 47 of Set 1 | thinadhoo
# Processing Record 48 of Set 1 | maceio
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | laplace
# Processing Record 2 of Set 2 | pisco
# Processing Record 3 of Set 2 | namatanai
# Processing Record 4 of Set 2 | vardo
# Processing Record 5 of Set 2 | tongchuan
# Processing Record 6 of Set 2 | atuona
# Processing Record 7 of Set 2 | lebu
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | skibotn
# Processing Record 10 of Set 2 | castro
# Processing Record 11 of Set 2 | hanchuan
# Processing Record 12 of Set 2 | muros
# Processing Record 13 of Set 2 | saint george
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | chuy
# Processing Record 19 of Set 2 | xingyi
# Processing Record 20 of Set 2 | lahijan
# Processing Record 21 of Set 2 | kahului
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | payo
# Processing Record 24 of Set 2 | kutum
# Processing Record 25 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 2 | perry
# Processing Record 27 of Set 2 | kruisfontein
# Processing Record 28 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 2 | la libertad
# Processing Record 30 of Set 2 | eureka
# Processing Record 31 of Set 2 | khani
# Processing Record 32 of Set 2 | sao filipe
# Processing Record 33 of Set 2 | orsk
# Processing Record 34 of Set 2 | la ligua
# Processing Record 35 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 2 | berlevag
# Processing Record 37 of Set 2 | saldanha
# Processing Record 38 of Set 2 | venice
# Processing Record 39 of Set 2 | marawi
# Processing Record 40 of Set 2 | bombo
# Processing Record 41 of Set 2 | samarai
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | samfya
# Processing Record 44 of Set 2 | acarau
# Processing Record 45 of Set 2 | carnarvon
# Processing Record 46 of Set 2 | barrow
# Processing Record 47 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 2 | chokurdakh
# Processing Record 49 of Set 2 | chincha alta
# Processing Record 50 of Set 2 | sistranda
# Processing Record 1 of Set 3 | tikrit
# Processing Record 2 of Set 3 | namtsy
# Processing Record 3 of Set 3 | narsaq
# Processing Record 4 of Set 3 | abakaliki
# Processing Record 5 of Set 3 | severo-kurilsk
# Processing Record 6 of Set 3 | kodiak
# Processing Record 7 of Set 3 | capellania
# Processing Record 8 of Set 3 | lanzhou
# Processing Record 9 of Set 3 | isiolo
# Processing Record 10 of Set 3 | salinopolis
# Processing Record 11 of Set 3 | port hedland
# Processing Record 12 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 3 | vallenar
# Processing Record 14 of Set 3 | lompoc
# Processing Record 15 of Set 3 | busselton
# Processing Record 16 of Set 3 | alice springs
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | sibolga
# Processing Record 19 of Set 3 | caucaia
# Processing Record 20 of Set 3 | mandera
# Processing Record 21 of Set 3 | qurayyat
# Processing Record 22 of Set 3 | guerrero negro
# Processing Record 23 of Set 3 | kamaishi
# Processing Record 24 of Set 3 | moerai
# Processing Record 25 of Set 3 | ilulissat
# Processing Record 26 of Set 3 | klaksvik
# Processing Record 27 of Set 3 | new norfolk
# Processing Record 28 of Set 3 | saskylakh
# Processing Record 29 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 3 | flin flon
# Processing Record 31 of Set 3 | tuktoyaktuk
# Processing Record 32 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 33 of Set 3 | port elizabeth
# Processing Record 34 of Set 3 | wasilla
# Processing Record 35 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 3 | yar-sale
# Processing Record 37 of Set 3 | lotofaga
# Processing Record 38 of Set 3 | ust-kuyga
# Processing Record 39 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 3 | dingle
# Processing Record 41 of Set 3 | hobyo
# Processing Record 42 of Set 3 | kawalu
# Processing Record 43 of Set 3 | tasiilaq
# Processing Record 44 of Set 3 | padang
# Processing Record 45 of Set 3 | okato
# Processing Record 46 of Set 3 | mariel
# Processing Record 47 of Set 3 | san ignacio
# Processing Record 48 of Set 3 | san patricio
# Processing Record 49 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 3 | acapulco
# Processing Record 1 of Set 4 | rincon
# Processing Record 2 of Set 4 | mahebourg
# Processing Record 3 of Set 4 | mokhsogollokh
# Processing Record 4 of Set 4 | waipawa
# Processing Record 5 of Set 4 | chippewa falls
# Processing Record 6 of Set 4 | bow island
# Processing Record 7 of Set 4 | vaini
# Processing Record 8 of Set 4 | tiznit
# Processing Record 9 of Set 4 | morant bay
# Processing Record 10 of Set 4 | nanortalik
# Processing Record 11 of Set 4 | moron
# Processing Record 12 of Set 4 | cockburn town
# Processing Record 13 of Set 4 | vao
# Processing Record 14 of Set 4 | kargasok
# Processing Record 15 of Set 4 | libreville
# Processing Record 16 of Set 4 | college
# Processing Record 17 of Set 4 | hilo
# Processing Record 18 of Set 4 | riyadh
# Processing Record 19 of Set 4 | thompson
# Processing Record 20 of Set 4 | sorland
# Processing Record 21 of Set 4 | sibu
# Processing Record 22 of Set 4 | tashigang
# Processing Record 23 of Set 4 | sungai siput utara
# City not found. Skipping...
# Processing Record 24 of Set 4 | rio gallegos
# Processing Record 25 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 4 | talnakh
# Processing Record 27 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 4 | iranshahr
# Processing Record 29 of Set 4 | tura
# Processing Record 30 of Set 4 | leh
# Processing Record 31 of Set 4 | dunedin
# Processing Record 32 of Set 4 | la paz
# Processing Record 33 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 34 of Set 4 | kaeo
# Processing Record 35 of Set 4 | torbay
# Processing Record 36 of Set 4 | wladyslawowo
# Processing Record 37 of Set 4 | loikaw
# Processing Record 38 of Set 4 | qasigiannguit
# Processing Record 39 of Set 4 | yarada
# Processing Record 40 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 4 | salalah
# Processing Record 42 of Set 4 | slyudyanka
# Processing Record 43 of Set 4 | haflong
# Processing Record 44 of Set 4 | komsomolskiy
# Processing Record 45 of Set 4 | ivanivka
# Processing Record 46 of Set 4 | vostok
# Processing Record 47 of Set 4 | cuilapa
# Processing Record 48 of Set 4 | faanui
# Processing Record 49 of Set 4 | halifax
# Processing Record 50 of Set 4 | odweyne
# Processing Record 1 of Set 5 | aktas
# Processing Record 2 of Set 5 | san rafael
# Processing Record 3 of Set 5 | clyde river
# Processing Record 4 of Set 5 | zyryanka
# Processing Record 5 of Set 5 | bubaque
# Processing Record 6 of Set 5 | praia
# Processing Record 7 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 5 | vanderhoof
# Processing Record 9 of Set 5 | punta de bombon
# Processing Record 10 of Set 5 | quelimane
# Processing Record 11 of Set 5 | palmerston
# Processing Record 12 of Set 5 | dombarovskiy
# Processing Record 13 of Set 5 | lagoa
# Processing Record 14 of Set 5 | mocuba
# Processing Record 15 of Set 5 | hervey bay
# Processing Record 16 of Set 5 | omsukchan
# Processing Record 17 of Set 5 | maksatikha
# Processing Record 18 of Set 5 | akyab
# Processing Record 19 of Set 5 | sola
# Processing Record 20 of Set 5 | mogadishu
# Processing Record 21 of Set 5 | nicoya
# Processing Record 22 of Set 5 | ancud
# Processing Record 23 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 24 of Set 5 | guthrie
# Processing Record 25 of Set 5 | chapais
# Processing Record 26 of Set 5 | ahipara
# Processing Record 27 of Set 5 | kommunar
# Processing Record 28 of Set 5 | kudahuvadhoo
# Processing Record 29 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 5 | port blair
# Processing Record 31 of Set 5 | coihueco
# Processing Record 32 of Set 5 | homer
# Processing Record 33 of Set 5 | matara
# Processing Record 34 of Set 5 | el wasta
# City not found. Skipping...
# Processing Record 35 of Set 5 | fairbanks
# Processing Record 36 of Set 5 | coahuayana
# Processing Record 37 of Set 5 | vanimo
# Processing Record 38 of Set 5 | karratha
# Processing Record 39 of Set 5 | longyearbyen
# Processing Record 40 of Set 5 | fort nelson
# Processing Record 41 of Set 5 | roald
# Processing Record 42 of Set 5 | istisu
# Processing Record 43 of Set 5 | codrington
# Processing Record 44 of Set 5 | san vicente
# Processing Record 45 of Set 5 | mount gambier
# Processing Record 46 of Set 5 | gizo
# Processing Record 47 of Set 5 | ous
# Processing Record 48 of Set 5 | cidreira
# Processing Record 49 of Set 5 | santa vitoria do palmar
# Processing Record 50 of Set 5 | la ronge
# Processing Record 1 of Set 6 | beira
# Processing Record 2 of Set 6 | bethel
# Processing Record 3 of Set 6 | tarakan
# Processing Record 4 of Set 6 | liwale
# Processing Record 5 of Set 6 | nyurba
# Processing Record 6 of Set 6 | ballina
# Processing Record 7 of Set 6 | cherskiy
# Processing Record 8 of Set 6 | hami
# Processing Record 9 of Set 6 | bintulu
# Processing Record 10 of Set 6 | kirakira
# Processing Record 11 of Set 6 | bambous virieux
# Processing Record 12 of Set 6 | roma
# Processing Record 13 of Set 6 | tiksi
# Processing Record 14 of Set 6 | olafsvik
# Processing Record 15 of Set 6 | hithadhoo
# Processing Record 16 of Set 6 | yulara
# Processing Record 17 of Set 6 | nsanje
# Processing Record 18 of Set 6 | kavaratti
# Processing Record 19 of Set 6 | constitucion
# Processing Record 20 of Set 6 | uromi
# Processing Record 21 of Set 6 | ribeira grande
# Processing Record 22 of Set 6 | alghero
# Processing Record 23 of Set 6 | sisimiut
# Processing Record 24 of Set 6 | kavieng
# Processing Record 25 of Set 6 | pringsewu
# Processing Record 26 of Set 6 | fortuna
# Processing Record 27 of Set 6 | davila
# Processing Record 28 of Set 6 | sungaipenuh
# Processing Record 29 of Set 6 | patea
# Processing Record 30 of Set 6 | aginskoye
# Processing Record 31 of Set 6 | grande-riviere
# City not found. Skipping...
# Processing Record 32 of Set 6 | esso
# Processing Record 33 of Set 6 | manjacaze
# Processing Record 34 of Set 6 | gainesville
# Processing Record 35 of Set 6 | severo-yeniseyskiy
# Processing Record 36 of Set 6 | pitimbu
# Processing Record 37 of Set 6 | hasaki
# Processing Record 38 of Set 6 | xunchang
# Processing Record 39 of Set 6 | ponta do sol
# Processing Record 40 of Set 6 | benguela
# Processing Record 41 of Set 6 | makakilo city
# Processing Record 42 of Set 6 | bonthe
# Processing Record 43 of Set 6 | hohhot
# Processing Record 44 of Set 6 | nisia floresta
# Processing Record 45 of Set 6 | butterworth
# Processing Record 46 of Set 6 | sinnamary
# Processing Record 47 of Set 6 | nongan
# Processing Record 48 of Set 6 | ossora
# Processing Record 49 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 6 | barentu
# Processing Record 1 of Set 7 | udachnyy
# Processing Record 2 of Set 7 | gamboma
# Processing Record 3 of Set 7 | aswan
# Processing Record 4 of Set 7 | yendi
# Processing Record 5 of Set 7 | daura
# Processing Record 6 of Set 7 | batagay-alyta
# Processing Record 7 of Set 7 | oum hadjer
# Processing Record 8 of Set 7 | bud
# Processing Record 9 of Set 7 | mount isa
# Processing Record 10 of Set 7 | ust-uda
# Processing Record 11 of Set 7 | kundiawa
# Processing Record 12 of Set 7 | seoul
# Processing Record 13 of Set 7 | rancho palos verdes
# Processing Record 14 of Set 7 | gunjur
# Processing Record 15 of Set 7 | ketchikan
# Processing Record 16 of Set 7 | poya
# Processing Record 17 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 7 | emiliano zapata
# Processing Record 19 of Set 7 | koboko
# Processing Record 20 of Set 7 | polyarnyy
# Processing Record 21 of Set 7 | paracuru
# Processing Record 22 of Set 7 | coihaique
# Processing Record 23 of Set 7 | grand gaube
# Processing Record 24 of Set 7 | victor harbor
# Processing Record 25 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 7 | lavrentiya
# Processing Record 27 of Set 7 | aranos
# Processing Record 28 of Set 7 | hamilton
# Processing Record 29 of Set 7 | mehamn
# Processing Record 30 of Set 7 | egvekinot
# Processing Record 31 of Set 7 | nouadhibou
# Processing Record 32 of Set 7 | nhulunbuy
# Processing Record 33 of Set 7 | dingli
# Processing Record 34 of Set 7 | namibe
# Processing Record 35 of Set 7 | cap malheureux
# Processing Record 36 of Set 7 | husavik
# Processing Record 37 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 7 | verkhnevilyuysk
# Processing Record 39 of Set 7 | vanavara
# Processing Record 40 of Set 7 | mangrol
# Processing Record 41 of Set 7 | provideniya
# Processing Record 42 of Set 7 | yambio
# Processing Record 43 of Set 7 | sitka
# Processing Record 44 of Set 7 | angouleme
# Processing Record 45 of Set 7 | grindavik
# Processing Record 46 of Set 7 | veraval
# Processing Record 47 of Set 7 | qitaihe
# Processing Record 48 of Set 7 | lorengau
# Processing Record 49 of Set 7 | middlebury
# Processing Record 50 of Set 7 | haringhata
# Processing Record 1 of Set 8 | pombas
# Processing Record 2 of Set 8 | benito juarez
# Processing Record 3 of Set 8 | te karaka
# Processing Record 4 of Set 8 | lensk
# Processing Record 5 of Set 8 | victoria
# Processing Record 6 of Set 8 | sobolevo
# Processing Record 7 of Set 8 | aldan
# Processing Record 8 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 10 of Set 8 | baker city
# Processing Record 11 of Set 8 | saint-francois
# Processing Record 12 of Set 8 | raudeberg
# Processing Record 13 of Set 8 | redlands
# Processing Record 14 of Set 8 | laguna
# Processing Record 15 of Set 8 | dubai
# Processing Record 16 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 17 of Set 8 | semirara
# Processing Record 18 of Set 8 | katsuura
# Processing Record 19 of Set 8 | taltal
# Processing Record 20 of Set 8 | labuhan
# Processing Record 21 of Set 8 | homberg
# Processing Record 22 of Set 8 | margate
# Processing Record 23 of Set 8 | san cristobal
# Processing Record 24 of Set 8 | wembley
# Processing Record 25 of Set 8 | fort morgan
# Processing Record 26 of Set 8 | voh
# Processing Record 27 of Set 8 | dentsville
# Processing Record 28 of Set 8 | salinas
# Processing Record 29 of Set 8 | ust-maya
# Processing Record 30 of Set 8 | san lawrenz
# Processing Record 31 of Set 8 | bathsheba
# Processing Record 32 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 33 of Set 8 | areosa
# Processing Record 34 of Set 8 | montemorelos
# Processing Record 35 of Set 8 | novovarshavka
# Processing Record 36 of Set 8 | rakiv lis
# Processing Record 37 of Set 8 | damghan
# Processing Record 38 of Set 8 | lyuban
# Processing Record 39 of Set 8 | solnechnogorsk
# Processing Record 40 of Set 8 | vila velha
# Processing Record 41 of Set 8 | sorong
# Processing Record 42 of Set 8 | boa vista
# Processing Record 43 of Set 8 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 44 of Set 8 | mathbaria
# Processing Record 45 of Set 8 | sao goncalo do sapucai
# Processing Record 46 of Set 8 | havelock
# Processing Record 47 of Set 8 | rolla
# Processing Record 48 of Set 8 | aguimes
# Processing Record 49 of Set 8 | marrakesh
# Processing Record 50 of Set 8 | krutikha
# Processing Record 1 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 9 | krasnoselkup
# Processing Record 3 of Set 9 | vidim
# Processing Record 4 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 5 of Set 9 | santa maria
# Processing Record 6 of Set 9 | jumla
# Processing Record 7 of Set 9 | pedernales
# Processing Record 8 of Set 9 | sadasivpet
# Processing Record 9 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 10 of Set 9 | makaryev
# Processing Record 11 of Set 9 | tabas
# Processing Record 12 of Set 9 | katherine
# Processing Record 13 of Set 9 | oranjestad
# Processing Record 14 of Set 9 | balkanabat
# Processing Record 15 of Set 9 | palmas
# Processing Record 16 of Set 9 | cururupu
# Processing Record 17 of Set 9 | kupang
# Processing Record 18 of Set 9 | imbituba
# Processing Record 19 of Set 9 | tambura
# Processing Record 20 of Set 9 | the valley
# Processing Record 21 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 9 | lieksa
# Processing Record 23 of Set 9 | marsh harbour
# Processing Record 24 of Set 9 | minna
# Processing Record 25 of Set 9 | daru
# Processing Record 26 of Set 9 | mazatlan
# Processing Record 27 of Set 9 | monrovia
# Processing Record 28 of Set 9 | acambay
# Processing Record 29 of Set 9 | broome
# Processing Record 30 of Set 9 | pevek
# Processing Record 31 of Set 9 | ewa beach
# Processing Record 32 of Set 9 | quatre cocos
# Processing Record 33 of Set 9 | saint anthony
# Processing Record 34 of Set 9 | sento se
# City not found. Skipping...
# Processing Record 35 of Set 9 | las vegas
# Processing Record 36 of Set 9 | ratnagiri
# Processing Record 37 of Set 9 | cabo san lucas
# Processing Record 38 of Set 9 | amlame
# Processing Record 39 of Set 9 | walvis bay
# Processing Record 40 of Set 9 | inhambane
# Processing Record 41 of Set 9 | berthierville
# Processing Record 42 of Set 9 | mackay
# Processing Record 43 of Set 9 | kiama
# Processing Record 44 of Set 9 | geraldton
# Processing Record 45 of Set 9 | meridian
# Processing Record 46 of Set 9 | lucapa
# Processing Record 47 of Set 9 | houston
# Processing Record 48 of Set 9 | cabo rojo
# Processing Record 49 of Set 9 | jilmah
# City not found. Skipping...
# Processing Record 50 of Set 9 | vacaville
# Processing Record 1 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 2 of Set 10 | shostka
# Processing Record 3 of Set 10 | lata
# Processing Record 4 of Set 10 | teknaf
# Processing Record 5 of Set 10 | portland
# Processing Record 6 of Set 10 | den helder
# Processing Record 7 of Set 10 | tshane
# Processing Record 8 of Set 10 | black river
# Processing Record 9 of Set 10 | nemuro
# Processing Record 10 of Set 10 | carballo
# Processing Record 11 of Set 10 | chara
# Processing Record 12 of Set 10 | maniitsoq
# Processing Record 13 of Set 10 | mountain home
# Processing Record 14 of Set 10 | ambon
# Processing Record 15 of Set 10 | bukama
# Processing Record 16 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 17 of Set 10 | mutare
# Processing Record 18 of Set 10 | klyuchi
# Processing Record 19 of Set 10 | copiapo
# Processing Record 20 of Set 10 | rawson
# Processing Record 21 of Set 10 | warmbad
# Processing Record 22 of Set 10 | ambulu
# Processing Record 23 of Set 10 | belaya gora
# Processing Record 24 of Set 10 | siwan
# Processing Record 25 of Set 10 | rudnogorsk
# Processing Record 26 of Set 10 | aras
# Processing Record 27 of Set 10 | pierre
# Processing Record 28 of Set 10 | saint-joseph
# Processing Record 29 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 30 of Set 10 | maneadero
# Processing Record 31 of Set 10 | xaltianguis
# Processing Record 32 of Set 10 | shalinskoye
# Processing Record 33 of Set 10 | mecca
# Processing Record 34 of Set 10 | big spring
# Processing Record 35 of Set 10 | ayagoz
# Processing Record 36 of Set 10 | bang saphan
# Processing Record 37 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 38 of Set 10 | umm kaddadah
# Processing Record 39 of Set 10 | kailua
# Processing Record 40 of Set 10 | olinda
# Processing Record 41 of Set 10 | broken hill
# Processing Record 42 of Set 10 | ntcheu
# Processing Record 43 of Set 10 | port lavaca
# Processing Record 44 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 10 | nelson bay
# Processing Record 46 of Set 10 | bambanglipuro
# Processing Record 47 of Set 10 | rulenge
# Processing Record 48 of Set 10 | krasnozerskoye
# Processing Record 49 of Set 10 | abu kamal
# Processing Record 50 of Set 10 | nara
# Processing Record 1 of Set 11 | kaniama
# Processing Record 2 of Set 11 | icod de los vinos
# Processing Record 3 of Set 11 | zaplyusye
# City not found. Skipping...
# Processing Record 4 of Set 11 | dhidhdhoo
# Processing Record 5 of Set 11 | mayo
# Processing Record 6 of Set 11 | pacific grove
# Processing Record 7 of Set 11 | abu dhabi
# Processing Record 8 of Set 11 | kota kinabalu
# Processing Record 9 of Set 11 | caravelas
# Processing Record 10 of Set 11 | hirara
# Processing Record 11 of Set 11 | biak
# Processing Record 12 of Set 11 | miramar
# Processing Record 13 of Set 11 | iquique
# Processing Record 14 of Set 11 | pindushi
# Processing Record 15 of Set 11 | asau
# Processing Record 16 of Set 11 | turukhansk
# Processing Record 17 of Set 11 | saint-pierre
# Processing Record 18 of Set 11 | kachiry
# Processing Record 19 of Set 11 | pangnirtung
# Processing Record 20 of Set 11 | yumen
# Processing Record 21 of Set 11 | kotelnich
# Processing Record 22 of Set 11 | santiago del estero
# Processing Record 23 of Set 11 | oskaloosa
# Processing Record 24 of Set 11 | coquimbo
# Processing Record 25 of Set 11 | baguer
# Processing Record 26 of Set 11 | jalu
# Processing Record 27 of Set 11 | asyut
# Processing Record 28 of Set 11 | mahibadhoo
# Processing Record 29 of Set 11 | gejiu
# Processing Record 30 of Set 11 | naze
# Processing Record 31 of Set 11 | atar
# Processing Record 32 of Set 11 | tsabong
# Processing Record 33 of Set 11 | cuamba
# Processing Record 34 of Set 11 | beringovskiy
# Processing Record 35 of Set 11 | makokou
# Processing Record 36 of Set 11 | panama city
# Processing Record 37 of Set 11 | florianopolis
# Processing Record 38 of Set 11 | sao raimundo das mangabeiras
# Processing Record 39 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 11 | darien
# Processing Record 41 of Set 11 | quesnel
# Processing Record 42 of Set 11 | puerto asis
# Processing Record 43 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 11 | derzhavinsk
# Processing Record 45 of Set 11 | hongjiang
# Processing Record 46 of Set 11 | almeirim
# Processing Record 47 of Set 11 | lemesos
# City not found. Skipping...
# Processing Record 48 of Set 11 | urumqi
# Processing Record 49 of Set 11 | san pedro de macoris
# Processing Record 50 of Set 11 | half moon bay
# Processing Record 1 of Set 12 | port moresby
# Processing Record 2 of Set 12 | north bend
# Processing Record 3 of Set 12 | ko samui
# Processing Record 4 of Set 12 | beloha
# Processing Record 5 of Set 12 | kisangani
# Processing Record 6 of Set 12 | surovatikha
# Processing Record 7 of Set 12 | mgandu
# Processing Record 8 of Set 12 | piacabucu
# Processing Record 9 of Set 12 | iqaluit
# Processing Record 10 of Set 12 | sterling
# Processing Record 11 of Set 12 | zawiercie
# Processing Record 12 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 14 of Set 12 | emerald
# Processing Record 15 of Set 12 | maues
# Processing Record 16 of Set 12 | robertsport
# Processing Record 17 of Set 12 | touros
# Processing Record 18 of Set 12 | katobu
# Processing Record 19 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 12 | kieta
# Processing Record 21 of Set 12 | opuwo
# Processing Record 22 of Set 12 | strezhevoy
# Processing Record 23 of Set 12 | yerbogachen
# Processing Record 24 of Set 12 | faya
# Processing Record 25 of Set 12 | baykit
# Processing Record 26 of Set 12 | moscow
# Processing Record 27 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 28 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 12 | narasannapeta
# Processing Record 30 of Set 12 | saint-cyr-sur-loire
# Processing Record 31 of Set 12 | carutapera
# Processing Record 32 of Set 12 | ostrovnoy
# Processing Record 33 of Set 12 | kazuno
# Processing Record 34 of Set 12 | ampanihy
# Processing Record 35 of Set 12 | urengoy
# Processing Record 36 of Set 12 | varhaug
# Processing Record 37 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 38 of Set 12 | camana
# Processing Record 39 of Set 12 | buluang
# Processing Record 40 of Set 12 | antofagasta
# Processing Record 41 of Set 12 | rorvik
# Processing Record 42 of Set 12 | tunxi
# City not found. Skipping...
# Processing Record 43 of Set 12 | semnan
# Processing Record 44 of Set 12 | la huacana
# Processing Record 45 of Set 12 | denau
# City not found. Skipping...
# Processing Record 46 of Set 12 | gold coast
# Processing Record 47 of Set 12 | pathein
# Processing Record 48 of Set 12 | ardmore
# Processing Record 49 of Set 12 | suhbaatar
# Processing Record 50 of Set 12 | eyl
# Processing Record 1 of Set 13 | tra vinh
# Processing Record 2 of Set 13 | prince rupert
# Processing Record 3 of Set 13 | kishiwada
# Processing Record 4 of Set 13 | maua
# Processing Record 5 of Set 13 | plastun
# Processing Record 6 of Set 13 | ucar
# Processing Record 7 of Set 13 | san quintin
# Processing Record 8 of Set 13 | evensk
# Processing Record 9 of Set 13 | wanaka
# Processing Record 10 of Set 13 | tautira
# Processing Record 11 of Set 13 | adrar
# Processing Record 12 of Set 13 | pervomayskoye
# Processing Record 13 of Set 13 | porto novo
# Processing Record 14 of Set 13 | lodja
# Processing Record 15 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 13 | crossville
# Processing Record 17 of Set 13 | fulton
# Processing Record 18 of Set 13 | severodvinsk
# Processing Record 19 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 13 | shymkent
# Processing Record 21 of Set 13 | tulagi
# Processing Record 22 of Set 13 | alizai
# Processing Record 23 of Set 13 | dalbandin
# Processing Record 24 of Set 13 | awjilah
# Processing Record 25 of Set 13 | puno
# Processing Record 26 of Set 13 | tongren
# Processing Record 27 of Set 13 | fomboni
# Processing Record 28 of Set 13 | burnie
# Processing Record 29 of Set 13 | flinders
# Processing Record 30 of Set 13 | mananara
# Processing Record 31 of Set 13 | taoudenni
# Processing Record 32 of Set 13 | tromso
# Processing Record 33 of Set 13 | todos santos
# Processing Record 34 of Set 13 | pontes e lacerda
# Processing Record 35 of Set 13 | svetlyy
# Processing Record 36 of Set 13 | sidi ali
# Processing Record 37 of Set 13 | ekibastuz
# Processing Record 38 of Set 13 | huayang
# Processing Record 39 of Set 13 | alappuzha
# Processing Record 40 of Set 13 | goteborg
# City not found. Skipping...
# Processing Record 41 of Set 13 | kirovsk
# Processing Record 42 of Set 13 | zunyi
# Processing Record 43 of Set 13 | palmer
# Processing Record 44 of Set 13 | tongzi
# Processing Record 45 of Set 13 | santa isabel do rio negro
# Processing Record 46 of Set 13 | kassala
# Processing Record 47 of Set 13 | batticaloa
# Processing Record 48 of Set 13 | shache
# Processing Record 49 of Set 13 | upata
# Processing Record 50 of Set 13 | santa ana
# Processing Record 1 of Set 14 | khasan
# Processing Record 2 of Set 14 | sakakah
# Processing Record 3 of Set 14 | luderitz
# Processing Record 4 of Set 14 | san jose
# Processing Record 5 of Set 14 | nantucket
# Processing Record 6 of Set 14 | necochea
# Processing Record 7 of Set 14 | lodwar
# Processing Record 8 of Set 14 | abu zabad
# Processing Record 9 of Set 14 | tacoronte
# Processing Record 10 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 11 of Set 14 | fasa
# Processing Record 12 of Set 14 | muyezerskiy
# Processing Record 13 of Set 14 | chabahar
# Processing Record 14 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 14 | zarechnyy
# Processing Record 16 of Set 14 | surt
# Processing Record 17 of Set 14 | oktyabrskoye
# Processing Record 18 of Set 14 | westport
# Processing Record 19 of Set 14 | yushu
# Processing Record 20 of Set 14 | weligama
# Processing Record 21 of Set 14 | novichikha
# Processing Record 22 of Set 14 | mezen
# Processing Record 23 of Set 14 | bilibino
# Processing Record 24 of Set 14 | edd
# Processing Record 25 of Set 14 | anadyr
# Processing Record 26 of Set 14 | huanren
# Processing Record 27 of Set 14 | meulaboh
# Processing Record 28 of Set 14 | ugoofaaru
# Processing Record 29 of Set 14 | gobabis
# Processing Record 30 of Set 14 | westerland
# Processing Record 31 of Set 14 | sabzevar
# Processing Record 32 of Set 14 | huangchuan
# Processing Record 33 of Set 14 | kloulklubed
# Processing Record 34 of Set 14 | sur
# Processing Record 35 of Set 14 | swan hill
# Processing Record 36 of Set 14 | smithers
# Processing Record 37 of Set 14 | safaga
# Processing Record 38 of Set 14 | sembe
# Processing Record 39 of Set 14 | auki
# Processing Record 40 of Set 14 | pemberton
# Processing Record 41 of Set 14 | timaru
# Processing Record 42 of Set 14 | santa cruz de la palma
# Processing Record 43 of Set 14 | hambantota
# Processing Record 44 of Set 14 | alofi
# Processing Record 45 of Set 14 | sorochinsk
# Processing Record 46 of Set 14 | hualmay
# Processing Record 47 of Set 14 | beya
# Processing Record 48 of Set 14 | dapaong
# Processing Record 49 of Set 14 | angul
# Processing Record 50 of Set 14 | najran
# Processing Record 1 of Set 15 | alamogordo
# Processing Record 2 of Set 15 | otane
# Processing Record 3 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 4 of Set 15 | cairns
# Processing Record 5 of Set 15 | menongue
# Processing Record 6 of Set 15 | boyolangu
# Processing Record 7 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 8 of Set 15 | soyo
# Processing Record 9 of Set 15 | arua
# Processing Record 10 of Set 15 | alcantara
# Processing Record 11 of Set 15 | taxisco
# Processing Record 12 of Set 15 | cantaura
# Processing Record 13 of Set 15 | chumikan
# Processing Record 14 of Set 15 | maraa
# Processing Record 15 of Set 15 | kununurra
# Processing Record 16 of Set 15 | leningradskiy
# Processing Record 17 of Set 15 | xai-xai
# Processing Record 18 of Set 15 | auka
# Processing Record 19 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 15 | zhezkazgan
# Processing Record 21 of Set 15 | yenagoa
# Processing Record 22 of Set 15 | kuala terengganu
# Processing Record 23 of Set 15 | sao felix do xingu
# Processing Record 24 of Set 15 | yangambi
# Processing Record 25 of Set 15 | vila franca do campo
# Processing Record 26 of Set 15 | kyzyl-suu
# Processing Record 27 of Set 15 | teya
# Processing Record 28 of Set 15 | krasnogvardeyskiy
# Processing Record 29 of Set 15 | rensvik
# Processing Record 30 of Set 15 | dawlatabad
# Processing Record 31 of Set 15 | zenzeli
# Processing Record 32 of Set 15 | ginda
# Processing Record 33 of Set 15 | mango
# Processing Record 34 of Set 15 | poum
# Processing Record 35 of Set 15 | kosh-agach
# Processing Record 36 of Set 15 | san mateo del mar
# Processing Record 37 of Set 15 | bulgan
# Processing Record 38 of Set 15 | zhanaozen
# Processing Record 39 of Set 15 | kaabong
# Processing Record 40 of Set 15 | tezu
# Processing Record 41 of Set 15 | bilma
# Processing Record 42 of Set 15 | abbeville
# Processing Record 43 of Set 15 | kesennuma
# City not found. Skipping...
# Processing Record 44 of Set 15 | donskoy
# Processing Record 45 of Set 15 | marktheidenfeld
# Processing Record 46 of Set 15 | marsa matruh
# Processing Record 47 of Set 15 | bollnas
# Processing Record 48 of Set 15 | galesong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the city count to confirm sufficient count.
len(city_data)
# Out:
# 684

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                 City      Lat       Lng Current Description  Max Temp  \
# 0        Yellowknife  62.4560 -114.3525          light snow      8.60
# 1  Sao Joao Da Barra -21.6403  -41.0511     overcast clouds     76.08
# 2         Moses Lake  47.1301 -119.2781     overcast clouds     42.80
# 3         Cedar City  37.6775 -113.0619           clear sky     26.60
# 4           Carbonia  39.1672    8.5222       broken clouds     53.60
#
#    Humidity  Cloudiness  Wind Speed Country                 Date
# 0        85          75        8.05      CA  2021-01-13 04:24:26
# 1        86          94       14.38      BR  2021-01-13 04:22:33
# 2        87          90       16.46      US  2021-01-13 04:24:27
# 3        54           1        4.61      US  2021-01-13 04:24:27
# 4        87          75       20.71      IT  2021-01-13 04:24:27

# %%
new_column_order=["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head()
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0        Yellowknife      CA  2021-01-13 04:24:26  62.4560 -114.3525
# 1  Sao Joao Da Barra      BR  2021-01-13 04:22:33 -21.6403  -41.0511
# 2         Moses Lake      US  2021-01-13 04:24:27  47.1301 -119.2781
# 3         Cedar City      US  2021-01-13 04:24:27  37.6775 -113.0619
# 4           Carbonia      IT  2021-01-13 04:24:27  39.1672    8.5222
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0      8.60        85          75        8.05          light snow
# 1     76.08        86          94       14.38     overcast clouds
# 2     42.80        87          90       16.46     overcast clouds
# 3     26.60        54           1        4.61           clear sky
# 4     53.60        87          75       20.71       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
